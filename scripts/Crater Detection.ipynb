# %%
import pycda

# %%
from pycda.sample_data import get_sample_image
image = get_sample_image()
image.show();

# %%
cda = pycda.CDA()
detections = cda.predict(image)
detections.head(4)
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# C:\anaconda3\lib\site-packages\pycda\extractors.py:46: UserWarning: The argument 'neighbors' is deprecated and will be removed in scikit-image 0.18, use 'connectivity' instead. For neighbors=4, use connectivity=1
#   labels = measure.label(filtered, neighbors=4, background=0)
#   lat  long   diameter
# 0  21    30  44.021252
# 1  17  1165  49.789531
# 2  19  1320  44.323906
# 5  21  1680  30.298609

# %%
prediction = cda.get_prediction(image)
prediction.set_scale(12.5)
prediction.show()
# Out:
# C:\anaconda3\lib\site-packages\pycda\extractors.py:46: UserWarning: The argument 'neighbors' is deprecated and will be removed in scikit-image 0.18, use 'connectivity' instead. For neighbors=4, use connectivity=1
#   labels = measure.label(filtered, neighbors=4, background=0)

# %%
from pycda.error_stats import ErrorAnalyzer
from pycda.sample_data import get_sample_csv

prediction.known_craters = get_sample_csv()
an = ErrorAnalyzer()
an.analyze(prediction)
# Out:
# 220 craters were properly detected.
# Matching complete!
#
# ==================================================
#
# Detection Percentage: 53.8%
#
# Precision: 0.69
#
# Recall: 0.54
#
# F1-Score: 0.61
#
# False Discovery Rate: 0.31
#
# False Negative Rate: 0.46
#
# Branching Factor:  0.44
#
# Quality Percentage: 43.5%
#
# ==================================================

# %%
an.show()
